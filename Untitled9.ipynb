# %%
import nbformat

path = "/content/Flight_Fare _Prediction Project  (1).ipynb"

try:
    nb = nbformat.read(path, as_version=4)
    nbformat.validate(nb)
    print("✅ Notebook is valid")
except Exception as e:
    print("❌ Validation error:")
    print(e)
# Out:
# ✅ Notebook is valid

# %%
import os

#path = "/content/your_notebook.ipynb"
print(f"{os.path.getsize(path)/1024/1024:.2f} MB")
# Out:
# 0.75 MB

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
